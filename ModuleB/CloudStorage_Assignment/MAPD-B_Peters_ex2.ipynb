# %% [markdown]
# <img align="right" width="200" height="200" src="https://avatars3.githubusercontent.com/u/43672704?s=400&u=7f10d18e6375065a2bd501c9cfd59a2ac6ad0f80&v=4">
#
# # MAPD B final project - Data Management
#
# **Authors:**
# * Alessandro Lambertini - ID: 1242885
# * Michele Guadagnini    - ID: 1230663

# %% [markdown]
# # Exercise 2 - Cryptography

# %% [markdown]
# We received an encrypted message: **K]amua!kv\\$huvt** <br>
# We know that it has been encrypted by adding to the ASCII value of each original character:
# * a secret *key*
# * a variable called *nonce* that represent the position index of the character in the message
#
# In formula:
# `encoded_character[i] = character[i] + key + nonce(i)`

# %% [markdown]
# ## 2.1) Is this symmetric or asymmetric encryption? Explain why.

# %% [markdown]
# The message has been encrypted with a **symmetric** encryption technique since to decrypt it we need to have the same key used to encrypt it, while in asymmetric encryption 2 different keys are used for encryption and decryption.

# %% [markdown]
# ## 2.2) Message decryption

# %% [markdown]
# To decrypt the message we have to:
# * retrieve tha ASCII sequence of the encrypted message;
# * reverse the formula above to get the ASCII sequence of the original message:
#     `character[i] = encoded_character[i] - key - nonce(i)`
# * convert back the ASCII sequence obtained into the original message.
# <br>
#
# Since the *key* value is not known, we need to test all the possible values, and, taking into account that the ASCII code ranges from 0 to 255, we can limit our search within this range.

# %% [markdown]
# ### 2.2.1) Brute force program

# %%
EncryptedMessage = "K]amua!kv$huvt"
print("The encrypted message is: ", repr(EncryptedMessage))

MessageLen = len(EncryptedMessage)

PossibleMessages = []
print("Brute force decryption: ")
for key in range(0,256):
    DecryptedMessage = ""
    for nonce in range(MessageLen):
        # reverting the encryption formula
        DecryptedMessage_ASCII = ord(EncryptedMessage[nonce]) - key - nonce
        
        # checking for out of range index
        if DecryptedMessage_ASCII < 0: 
            DecryptedMessage_ASCII += 256
            
        # rebuilding the (possibly) original message
        DecryptedMessage += chr( DecryptedMessage_ASCII )
        
    PossibleMessages.append(DecryptedMessage)    
    print("  key: ", key, " -->  Message: ", repr(DecryptedMessage))
# Out:
# The encrypted message is:  'K]amua!kv$huvt'
# Brute force decryption:
#   key:  0  -->  Message:  'K\\_jq\\\x1bdn\x1b^jjg'
#   key:  1  -->  Message:  'J[^ip[\x1acm\x1a]iif'
#   key:  2  -->  Message:  'IZ]hoZ\x19bl\x19\\hhe'
#   key:  3  -->  Message:  'HY\\gnY\x18ak\x18[ggd'
#   key:  4  -->  Message:  'GX[fmX\x17`j\x17Zffc'
#   key:  5  -->  Message:  'FWZelW\x16_i\x16Yeeb'
#   key:  6  -->  Message:  'EVYdkV\x15^h\x15Xdda'
#   key:  7  -->  Message:  'DUXcjU\x14]g\x14Wcc`'
#   key:  8  -->  Message:  'CTWbiT\x13\\f\x13Vbb_'
#   key:  9  -->  Message:  'BSVahS\x12[e\x12Uaa^'
#   key:  10  -->  Message:  'ARU`gR\x11Zd\x11T``]'
#   key:  11  -->  Message:  '@QT_fQ\x10Yc\x10S__\\'
#   key:  12  -->  Message:  '?PS^eP\x0fXb\x0fR^^['
#   key:  13  -->  Message:  '>OR]dO\x0eWa\x0eQ]]Z'
#   key:  14  -->  Message:  '=NQ\\cN\rV`\rP\\\\Y'
#   key:  15  -->  Message:  '<MP[bM\x0cU_\x0cO[[X'
#   key:  16  -->  Message:  ';LOZaL\x0bT^\x0bNZZW'
#   key:  17  -->  Message:  ':KNY`K\nS]\nMYYV'
#   key:  18  -->  Message:  '9JMX_J\tR\\\tLXXU'
#   key:  19  -->  Message:  '8ILW^I\x08Q[\x08KWWT'
#   key:  20  -->  Message:  '7HKV]H\x07PZ\x07JVVS'
#   key:  21  -->  Message:  '6GJU\\G\x06OY\x06IUUR'
#   key:  22  -->  Message:  '5FIT[F\x05NX\x05HTTQ'
#   key:  23  -->  Message:  '4EHSZE\x04MW\x04GSSP'
#   key:  24  -->  Message:  '3DGRYD\x03LV\x03FRRO'
#   key:  25  -->  Message:  '2CFQXC\x02KU\x02EQQN'
#   key:  26  -->  Message:  '1BEPWB\x01JT\x01DPPM'
#   key:  27  -->  Message:  '0ADOVA\x00IS\x00COOL'
#   key:  28  -->  Message:  '/@CNU@ÿHRÿBNNK'
#   key:  29  -->  Message:  '.?BMT?þGQþAMMJ'
#   key:  30  -->  Message:  '->ALS>ýFPý@LLI'
#   key:  31  -->  Message:  ',=@KR=üEOü?KKH'
#   key:  32  -->  Message:  '+<?JQ<ûDNû>JJG'
#   key:  33  -->  Message:  '*;>IP;úCMú=IIF'
#   key:  34  -->  Message:  '):=HO:ùBLù<HHE'
#   key:  35  -->  Message:  '(9<GN9øAKø;GGD'
#   key:  36  -->  Message:  "'8;FM8÷@J÷:FFC"
#   key:  37  -->  Message:  '&7:EL7ö?Iö9EEB'
#   key:  38  -->  Message:  '%69DK6õ>Hõ8DDA'
#   key:  39  -->  Message:  '$58CJ5ô=Gô7CC@'
#   key:  40  -->  Message:  '#47BI4ó<Fó6BB?'
#   key:  41  -->  Message:  '"36AH3ò;Eò5AA>'
#   key:  42  -->  Message:  '!25@G2ñ:Dñ4@@='
#   key:  43  -->  Message:  ' 14?F1ð9Cð3??<'
#   key:  44  -->  Message:  '\x1f03>E0ï8Bï2>>;'
#   key:  45  -->  Message:  '\x1e/2=D/î7Aî1==:'
#   key:  46  -->  Message:  '\x1d.1<C.í6@í0<<9'
#   key:  47  -->  Message:  '\x1c-0;B-ì5?ì/;;8'
#   key:  48  -->  Message:  '\x1b,/:A,ë4>ë.::7'
#   key:  49  -->  Message:  '\x1a+.9@+ê3=ê-996'
#   key:  50  -->  Message:  '\x19*-8?*é2<é,885'
#   key:  51  -->  Message:  '\x18),7>)è1;è+774'
#   key:  52  -->  Message:  '\x17(+6=(ç0:ç*663'
#   key:  53  -->  Message:  "\x16'*5<'æ/9æ)552"
#   key:  54  -->  Message:  '\x15&)4;&å.8å(441'
#   key:  55  -->  Message:  "\x14%(3:%ä-7ä'330"
#   key:  56  -->  Message:  "\x13$'29$ã,6ã&22/"
#   key:  57  -->  Message:  '\x12#&18#â+5â%11.'
#   key:  58  -->  Message:  '\x11"%07"á*4á$00-'
#   key:  59  -->  Message:  '\x10!$/6!à)3à#//,'
#   key:  60  -->  Message:  '\x0f #.5 ß(2ß"..+'
#   key:  91  -->  Message:  'ð\x01\x04\x0f\x16\x01À\t\x13À\x03\x0f\x0f\x0c'
#   key:  92  -->  Message:  'ï\x00\x03\x0e\x15\x00¿\x08\x12¿\x02\x0e\x0e\x0b'
#   key:  93  -->  Message:  'îÿ\x02\r\x14ÿ¾\x07\x11¾\x01\r\r\n'
#   key:  94  -->  Message:  'íþ\x01\x0c\x13þ½\x06\x10½\x00\x0c\x0c\t'
#   key:  95  -->  Message:  'ìý\x00\x0b\x12ý¼\x05\x0f¼ÿ\x0b\x0b\x08'
#   key:  96  -->  Message:  'ëüÿ\n\x11ü»\x04\x0e»þ\n\n\x07'
#   key:  97  -->  Message:  'êûþ\t\x10ûº\x03\rºý\t\t\x06'
#   key:  98  -->  Message:  'éúý\x08\x0fú¹\x02\x0c¹ü\x08\x08\x05'
#   key:  99  -->  Message:  'èùü\x07\x0eù¸\x01\x0b¸û\x07\x07\x04'
#   key:  100  -->  Message:  'çøû\x06\rø·\x00\n·ú\x06\x06\x03'
#   key:  101  -->  Message:  'æ÷ú\x05\x0c÷¶ÿ\t¶ù\x05\x05\x02'
#   key:  102  -->  Message:  'åöù\x04\x0böµþ\x08µø\x04\x04\x01'
#   key:  103  -->  Message:  'äõø\x03\nõ´ý\x07´÷\x03\x03\x00'
#   key:  104  -->  Message:  'ãô÷\x02\tô³ü\x06³ö\x02\x02ÿ'
#   key:  105  -->  Message:  'âóö\x01\x08ó²û\x05²õ\x01\x01þ'
#   key:  106  -->  Message:  'áòõ\x00\x07ò±ú\x04±ô\x00\x00ý'
#   key:  107  -->  Message:  'àñôÿ\x06ñ°ù\x03°óÿÿü'
#   key:  108  -->  Message:  'ßðóþ\x05ð¯ø\x02¯òþþû'
#   key:  109  -->  Message:  'Þïòý\x04ï®÷\x01®ñýýú'
#   key:  110  -->  Message:  'Ýîñü\x03î\xadö\x00\xadðüüù'
#   key:  111  -->  Message:  'Üíðû\x02í¬õÿ¬ïûûø'
#   key:  112  -->  Message:  'Ûìïú\x01ì«ôþ«îúú÷'
#   key:  113  -->  Message:  'Úëîù\x00ëªóýªíùùö'
#   key:  114  -->  Message:  'Ùêíøÿê©òü©ìøøõ'
#   key:  115  -->  Message:  'Øéì÷þé¨ñû¨ë÷÷ô'
#   key:  116  -->  Message:  '×èëöýè§ðú§êööó'
#   key:  117  -->  Message:  'Öçêõüç¦ïù¦éõõò'
#   key:  118  -->  Message:  'Õæéôûæ¥îø¥èôôñ'
#   key:  119  -->  Message:  'Ôåèóúå¤í÷¤çóóð'
#   key:  120  -->  Message:  'Óäçòùä£ìö£æòòï'
#   key:  121  -->  Message:  'Òãæñøã¢ëõ¢åññî'
#   key:  122  -->  Message:  'Ñâåð÷â¡êô¡äððí'
#   key:  123  -->  Message:  'Ðáäïöá\xa0éó\xa0ãïïì'
#   key:  124  -->  Message:  'Ïàãîõà\x9fèò\x9fâîîë'
#   key:  125  -->  Message:  'Îßâíôß\x9eçñ\x9eáííê'
#   key:  126  -->  Message:  'ÍÞáìóÞ\x9dæð\x9dàììé'
#   key:  127  -->  Message:  'ÌÝàëòÝ\x9cåï\x9cßëëè'
#   key:  161  -->  Message:  'ª»¾ÉÐ»zÃÍz½ÉÉÆ'
#   key:  162  -->  Message:  '©º½ÈÏºyÂÌy¼ÈÈÅ'
#   key:  163  -->  Message:  '¨¹¼ÇÎ¹xÁËx»ÇÇÄ'
#   key:  164  -->  Message:  '§¸»ÆÍ¸wÀÊwºÆÆÃ'
#   key:  165  -->  Message:  '¦·ºÅÌ·v¿Év¹ÅÅÂ'
#   key:  166  -->  Message:  '¥¶¹ÄË¶u¾Èu¸ÄÄÁ'
#   key:  167  -->  Message:  '¤µ¸ÃÊµt½Çt·ÃÃÀ'
#   key:  168  -->  Message:  '£´·ÂÉ´s¼Æs¶ÂÂ¿'
#   key:  169  -->  Message:  '¢³¶ÁÈ³r»ÅrµÁÁ¾'
#   key:  170  -->  Message:  '¡²µÀÇ²qºÄq´ÀÀ½'
#   key:  171  -->  Message:  '\xa0±´¿Æ±p¹Ãp³¿¿¼'
#   key:  172  -->  Message:  '\x9f°³¾Å°o¸Âo²¾¾»'
#   key:  173  -->  Message:  '\x9e¯²½Ä¯n·Án±½½º'
#   key:  174  -->  Message:  '\x9d®±¼Ã®m¶Àm°¼¼¹'
#   key:  175  -->  Message:  '\x9c\xad°»Â\xadlµ¿l¯»»¸'
#   key:  176  -->  Message:  '\x9b¬¯ºÁ¬k´¾k®ºº·'
#   key:  177  -->  Message:  '\x9a«®¹À«j³½j\xad¹¹¶'
#   key:  178  -->  Message:  '\x99ª\xad¸¿ªi²¼i¬¸¸µ'
#   key:  179  -->  Message:  '\x98©¬·¾©h±»h«··´'
#   key:  180  -->  Message:  '\x97¨«¶½¨g°ºgª¶¶³'
#   key:  181  -->  Message:  '\x96§ªµ¼§f¯¹f©µµ²'
#   key:  182  -->  Message:  '\x95¦©´»¦e®¸e¨´´±'
#   key:  183  -->  Message:  '\x94¥¨³º¥d\xad·d§³³°'
#   key:  184  -->  Message:  '\x93¤§²¹¤c¬¶c¦²²¯'
#   key:  185  -->  Message:  '\x92£¦±¸£b«µb¥±±®'
#   key:  186  -->  Message:  '\x91¢¥°·¢aª´a¤°°\xad'
#   key:  187  -->  Message:  '\x90¡¤¯¶¡`©³`£¯¯¬'
#   key:  188  -->  Message:  '\x8f\xa0£®µ\xa0_¨²_¢®®«'
#   key:  189  -->  Message:  '\x8e\x9f¢\xad´\x9f^§±^¡\xad\xadª'
#   key:  190  -->  Message:  '\x8d\x9e¡¬³\x9e]¦°]\xa0¬¬©'
#   key:  191  -->  Message:  '\x8c\x9d\xa0«²\x9d\\¥¯\\\x9f««¨'
#   key:  192  -->  Message:  '\x8b\x9c\x9fª±\x9c[¤®[\x9eªª§'
#   key:  193  -->  Message:  '\x8a\x9b\x9e©°\x9bZ£\xadZ\x9d©©¦'
#   key:  194  -->  Message:  '\x89\x9a\x9d¨¯\x9aY¢¬Y\x9c¨¨¥'
#   key:  195  -->  Message:  '\x88\x99\x9c§®\x99X¡«X\x9b§§¤'
#   key:  196  -->  Message:  '\x87\x98\x9b¦\xad\x98W\xa0ªW\x9a¦¦£'
#   key:  197  -->  Message:  '\x86\x97\x9a¥¬\x97V\x9f©V\x99¥¥¢'
#   key:  198  -->  Message:  '\x85\x96\x99¤«\x96U\x9e¨U\x98¤¤¡'
#   key:  199  -->  Message:  '\x84\x95\x98£ª\x95T\x9d§T\x97££\xa0'
#   key:  200  -->  Message:  '\x83\x94\x97¢©\x94S\x9c¦S\x96¢¢\x9f'
#   key:  201  -->  Message:  '\x82\x93\x96¡¨\x93R\x9b¥R\x95¡¡\x9e'
#   key:  202  -->  Message:  '\x81\x92\x95\xa0§\x92Q\x9a¤Q\x94\xa0\xa0\x9d'
#   key:  203  -->  Message:  '\x80\x91\x94\x9f¦\x91P\x99£P\x93\x9f\x9f\x9c'
#   key:  204  -->  Message:  '\x7f\x90\x93\x9e¥\x90O\x98¢O\x92\x9e\x9e\x9b'
#   key:  205  -->  Message:  '~\x8f\x92\x9d¤\x8fN\x97¡N\x91\x9d\x9d\x9a'
#   key:  206  -->  Message:  '}\x8e\x91\x9c£\x8eM\x96\xa0M\x90\x9c\x9c\x99'
#   key:  207  -->  Message:  '|\x8d\x90\x9b¢\x8dL\x95\x9fL\x8f\x9b\x9b\x98'
#   key:  208  -->  Message:  '{\x8c\x8f\x9a¡\x8cK\x94\x9eK\x8e\x9a\x9a\x97'
#   key:  209  -->  Message:  'z\x8b\x8e\x99\xa0\x8bJ\x93\x9dJ\x8d\x99\x99\x96'
#   key:  210  -->  Message:  'y\x8a\x8d\x98\x9f\x8aI\x92\x9cI\x8c\x98\x98\x95'
#   key:  211  -->  Message:  'x\x89\x8c\x97\x9e\x89H\x91\x9bH\x8b\x97\x97\x94'
#   key:  212  -->  Message:  'w\x88\x8b\x96\x9d\x88G\x90\x9aG\x8a\x96\x96\x93'
#   key:  213  -->  Message:  'v\x87\x8a\x95\x9c\x87F\x8f\x99F\x89\x95\x95\x92'
#   key:  214  -->  Message:  'u\x86\x89\x94\x9b\x86E\x8e\x98E\x88\x94\x94\x91'
#   key:  215  -->  Message:  't\x85\x88\x93\x9a\x85D\x8d\x97D\x87\x93\x93\x90'
#   key:  216  -->  Message:  's\x84\x87\x92\x99\x84C\x8c\x96C\x86\x92\x92\x8f'
#   key:  217  -->  Message:  'r\x83\x86\x91\x98\x83B\x8b\x95B\x85\x91\x91\x8e'
#   key:  218  -->  Message:  'q\x82\x85\x90\x97\x82A\x8a\x94A\x84\x90\x90\x8d'
#   key:  219  -->  Message:  'p\x81\x84\x8f\x96\x81@\x89\x93@\x83\x8f\x8f\x8c'
#   key:  220  -->  Message:  'o\x80\x83\x8e\x95\x80?\x88\x92?\x82\x8e\x8e\x8b'
#   key:  221  -->  Message:  'n\x7f\x82\x8d\x94\x7f>\x87\x91>\x81\x8d\x8d\x8a'
#   key:  222  -->  Message:  'm~\x81\x8c\x93~=\x86\x90=\x80\x8c\x8c\x89'
#   key:  223  -->  Message:  'l}\x80\x8b\x92}<\x85\x8f<\x7f\x8b\x8b\x88'
#   key:  224  -->  Message:  'k|\x7f\x8a\x91|;\x84\x8e;~\x8a\x8a\x87'
#   key:  225  -->  Message:  'j{~\x89\x90{:\x83\x8d:}\x89\x89\x86'
#   key:  226  -->  Message:  'iz}\x88\x8fz9\x82\x8c9|\x88\x88\x85'
#   key:  227  -->  Message:  'hy|\x87\x8ey8\x81\x8b8{\x87\x87\x84'
#   key:  228  -->  Message:  'gx{\x86\x8dx7\x80\x8a7z\x86\x86\x83'
#   key:  229  -->  Message:  'fwz\x85\x8cw6\x7f\x896y\x85\x85\x82'
#   key:  230  -->  Message:  'evy\x84\x8bv5~\x885x\x84\x84\x81'
#   key:  231  -->  Message:  'dux\x83\x8au4}\x874w\x83\x83\x80'
#   key:  232  -->  Message:  'ctw\x82\x89t3|\x863v\x82\x82\x7f'
#   key:  233  -->  Message:  'bsv\x81\x88s2{\x852u\x81\x81~'
#   key:  234  -->  Message:  'aru\x80\x87r1z\x841t\x80\x80}'
#   key:  235  -->  Message:  '`qt\x7f\x86q0y\x830s\x7f\x7f|'
#   key:  236  -->  Message:  '_ps~\x85p/x\x82/r~~{'
#   key:  237  -->  Message:  '^or}\x84o.w\x81.q}}z'
#   key:  238  -->  Message:  ']nq|\x83n-v\x80-p||y'
#   key:  239  -->  Message:  '\\mp{\x82m,u\x7f,o{{x'
#   key:  240  -->  Message:  '[loz\x81l+t~+nzzw'
#   key:  241  -->  Message:  'Zkny\x80k*s}*myyv'
#   key:  242  -->  Message:  'Yjmx\x7fj)r|)lxxu'
#   key:  243  -->  Message:  'Xilw~i(q{(kwwt'
#   key:  244  -->  Message:  "Whkv}h'pz'jvvs"
#   key:  245  -->  Message:  'Vgju|g&oy&iuur'
#   key:  246  -->  Message:  'Ufit{f%nx%httq'
#   key:  247  -->  Message:  'Tehsze$mw$gssp'
#   key:  248  -->  Message:  'Sdgryd#lv#frro'
#   key:  249  -->  Message:  'Rcfqxc"ku"eqqn'
#   key:  250  -->  Message:  'Qbepwb!jt!dppm'
#   key:  251  -->  Message:  'Padova is cool'
#   key:  252  -->  Message:  'O`cnu`\x1fhr\x1fbnnk'
#   key:  253  -->  Message:  'N_bmt_\x1egq\x1eammj'
#   key:  254  -->  Message:  'M^als^\x1dfp\x1d`lli'
#   key:  255  -->  Message:  'L]`kr]\x1ceo\x1c_kkh'

# %% [markdown]
# Checking visually the outputs, it is clear that the only message that makes sense is **Padova is cool** obtained with the **key = 251**.

# %% [markdown]
# ### 2.2.2) Dictionary approach

# %%
# bulding up the English dictionary
En_dict = {}
wordsfile = "/usr/share/dict/words"
with open(wordsfile) as ff:
    content = ff.readlines()

for word in content:
    En_dict[word.strip().lower()] = True #associate an existing word (key) with a True (value)
    
# using the dictionary approach
print("Dictionary approach selection: ")
words_count = {}
for (candidate, idx) in zip(PossibleMessages, range(len(PossibleMessages))):
    words_found = 0
    for word in candidate.split():
        if En_dict.get(word.lower(), False):
            words_found += 1
            
    words_count[idx] = words_found
    
max_key = max(words_count, key=words_count.get)
print("  key: ", max_key , " -->  Message: ", repr(PossibleMessages[max_key]))
# Out:
# Dictionary approach selection:
#   key:  251  -->  Message:  'Padova is cool'

# %% [markdown]
# As can be seen above, using the dictionary we are able to reduce all the possible keys to only one candidate. So, finally:
# * the correct key is **251**
# * the original message is **Padova is cool**.
